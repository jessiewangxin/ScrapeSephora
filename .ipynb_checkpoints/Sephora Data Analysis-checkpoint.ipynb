# %%
import pandas as pd
import numpy as np

veganproducts = pd.read_csv('veganproducts.csv')

# %%
#defining new variables
veganproducts['is_vegan']= ['Y' if cat =='vegan-skin-care' else 'N' for cat in veganproducts['category']]

#veganproducts['is_clean']= ['Y' if cat =='vegan-skin-care' else 'N' for cat in veganproducts['category']]
#veganproducts['eye_care']= ['Y' if cat =='vegan-skin-care' else 'N' for cat in veganproducts['category']]
#veganproducts['lip_care']= ['Y' if cat =='vegan-skin-care' else 'N' for cat in veganproducts['category']]
#veganproducts['moisturizer']= ['Y' if cat =='vegan-skin-care' else 'N' for cat in veganproducts['category']]

# %%
veganproducts
# Out:
#             category                      brand  \
# 0    vegan-skin-care             DRUNK ELEPHANT
# 1    vegan-skin-care                     TATCHA
# 2    vegan-skin-care                    LANEIGE
# 3    vegan-skin-care             SOL DE JANEIRO
# 4    vegan-skin-care             DRUNK ELEPHANT
# ..               ...                        ...
# 837  vegan-skin-care               THE ORDINARY
# 838  vegan-skin-care              HUM NUTRITION
# 839  vegan-skin-care                   ALGENIST
# 840  vegan-skin-care  DR. DENNIS GROSS SKINCARE
# 841  vegan-skin-care                    ORIGINS
#
#                                              prod_name     num_loves  \
# 0                     Protini™ Polypeptide Moisturizer  251.6K loves
# 1                                      The Water Cream  225.6K loves
# 2                                    Lip Sleeping Mask  403.8K loves
# 3                              Brazilian Bum Bum Cream    206K loves
# ...
