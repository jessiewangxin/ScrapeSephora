# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles

#importing the datasets 

veganproducts = pd.read_csv('veganproducts.csv')
cleanskincare = pd.read_csv('cleanskincare.csv')
eyecream_lipcare = pd.read_csv('eyecream_lipcare.csv')
moist_cleans = pd.read_csv('moist_cleans.csv')
sun_treatments = pd.read_csv('sun_treatments.csv')
skincare_data = pd.concat([eyecream_lipcare,moist_cleans,sun_treatments],ignore_index=True)

# %%
float("$10000.0".replace('$',''))
# Out:
# 10000.0

# %%
#REMOVE duplicates
skincare_data = skincare_data.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
#scrubbing price field
skincare_data['price_scrub'] = [float(i.replace('$','')) for i in skincare_data['price']]
#skincare_data

# %%
#defining new variables
veganproducts['is_vegan']= [1 if cat=='vegan-skin-care' else 0 for cat in veganproducts['category']]
cleanskincare['is_clean']=[1 if cat=='clean-skin-care' else 0 for cat in cleanskincare['category']]
#skincare_data['notvegan']= [1 if i==0 else 0 for i in skincare_data['is_vegan']]
#skincare_data['eye_care']= [1 if cat =='eye-treatment-dark-circle-treatment' else 0 for cat in skincare_data['category']]
#skincare_data['lip_care']= [1 if cat =='lip-treatments' else 0 for cat in skincare_data['category']]

# %%
#DEFINING RATING
skincare_data['rating'] = (skincare_data['num_five']*5 + \
                              skincare_data['num_four']*4 + \
                              skincare_data['num_three']*3 + \
                              skincare_data['num_two']*2 + \
                              skincare_data['num_one']*1) / (skincare_data['num_five'] + \
                                                 skincare_data['num_four'] +
                                                 skincare_data['num_three'] + 
                                                 skincare_data['num_two'] +
                                                 skincare_data['num_one'])

# %%
#left join the flags 
skincare_data2=pd.merge(skincare_data,veganproducts[['prod_name','is_vegan']], on='prod_name', how='left')
skincare_data3=pd.merge(skincare_data2,cleanskincare[['prod_name','is_clean']],on='prod_name',how='left')
skincare_data = skincare_data3

# %%
#skincare_data

# %%
skincare_data['is_vegan']=skincare_data['is_vegan'].fillna(0)
skincare_data['is_clean']=skincare_data['is_clean'].fillna(0)

# %%
skincare_data['sum_vegan_clean'] = skincare_data['is_vegan'] +skincare_data['is_clean']

# %%
skincare_data['sum_vegan_clean'] = skincare_data['is_vegan'] +skincare_data['is_clean']
skincare_data['vegan_and_clean'] = [1 if i==2 else 0 for i in skincare_data['sum_vegan_clean']]
skincare_data['vegan_only'] = np.where(skincare_data.is_vegan==1, \
                                      np.where(skincare_data.vegan_and_clean!=1,1,0),0)
skincare_data['clean_only'] = np.where(skincare_data.is_clean==1, \
                                      np.where(skincare_data.vegan_and_clean!=1,1,0),0)
skincare_data['all_other'] = np.where(skincare_data.is_vegan==0, \
                                      np.where(skincare_data.is_clean==0,1,0),0)

# %%
skincare_datasub = skincare_data[['category','vegan_only','clean_only','vegan_and_clean','all_other']]
skincare_datasub=skincare_datasub.groupby('category').agg(sum)

compare_cat= skincare_datasub

# %%
#compare_cat=compare_cat.reset_index()
#del compare_cat['index']
#compare_cat

compare_cat = compare_cat.sort_values('all_other')
compare_cat
# Out:
#                                      vegan_only  clean_only  vegan_and_clean  \
# category
# cleanser                                      9          28               34
# sunscreen-sun-protection                     16          21               36
# lip-treatments                                5          30               12
# eye-treatment-dark-circle-treatment          16          28               30
# facial-treatments                            97          71               86
# moisturizing-cream-oils-mists                76         114              162
#
#                                      all_other
# category
# cleanser                                   116
# sunscreen-sun-protection                   116
# lip-treatments                             129
# eye-treatment-dark-circle-treatment        147
# facial-treatments                          336
# moisturizing-cream-oils-mists              476

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


pos = list(range(len(compare_cat['vegan_only'])))
width = 0.175 
    
fig, ax = plt.subplots(figsize=(15,8))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        compare_cat['vegan_only'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224')

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        compare_cat['clean_only'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222')

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['post_score'] data,
        compare_cat['vegan_and_clean'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E') 

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*3 for p in pos], 
        #using df['post_score'] data,
        compare_cat['all_other'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#8A2BE2')



# Set the y axis label
ax.set_ylabel('Product Count')

# Set the chart's title
ax.set_title('Number of Products by Category')
             
# Set the labels for the x ticks
labels = ['Cleansers', 'Suncare','Lips','Eyes','Treatments','Moisturizer']
ax.set_xticklabels(labels)

# Setting the x-axis and y-axis limits
plt.xlim(0, max(pos)+width*5)
plt.ylim([0, max(compare_cat['vegan_only'] + compare_cat['clean_only'] + compare_cat['vegan_and_clean'] + compare_cat['all_other'])] )

# Adding the legend and showing the plot
plt.legend(['Vegan', 'Clean', 'Vegan and Clean', 'All Other'], loc='upper left')
plt.show()

# %%
#PRICE ANALYSIS

skincare_data['vegan_clean_price'] = skincare_data['vegan_and_clean'] * skincare_data['price_scrub']
skincare_data['vegan_price'] = skincare_data['vegan_only'] * skincare_data['price_scrub']
skincare_data['clean_price'] = skincare_data['clean_only'] * skincare_data['price_scrub']
skincare_data['other_price'] = skincare_data['all_other'] * skincare_data['price_scrub']

#skincare_data

# %%
skincare_datasub = skincare_data[['category','vegan_clean_price','vegan_price','clean_price','other_price', \
                                 'vegan_only','clean_only','vegan_and_clean','all_other']]
skincare_datasub=skincare_datasub.groupby('category').agg(sum)

compare_cat= skincare_datasub

# %%
compare_cat=compare_cat.reset_index()
compare_cat
# Out:
#                               category  vegan_clean_price  vegan_price  \
# 0                             cleanser              954.0       230.00
# 1  eye-treatment-dark-circle-treatment             1742.0      1212.00
# 2                    facial-treatments             5808.0      5365.59
# 3                       lip-treatments              237.5       120.00
# 4        moisturizing-cream-oils-mists             8902.0      4561.57
# 5             sunscreen-sun-protection             1360.0       644.00
#
#    clean_price  other_price  vegan_only  clean_only  vegan_and_clean  \
# 0      1054.00      3444.99           9          28               34
# 1      1728.99      9711.98          16          28               30
# 2      6702.98     24324.01          97          71               86
# 3       511.00      3455.00           5          30               12
# 4      7081.98     31815.47          76         114              162
# 5       837.00      5786.50          16          21               36
#
#    all_other
# 0        116
# 1        147
# 2        336
# 3        129
# 4        476
# 5        116

# %%
compare_cat = compare_cat.sort_values('all_other')
compare_cat

# %%
compare_cat['price_veganclean']=compare_cat['vegan_clean_price']/compare_cat['vegan_and_clean'] 
compare_cat['price_vegan']=compare_cat['vegan_price']/compare_cat['vegan_only'] 
compare_cat['price_clean']=compare_cat['clean_price']/compare_cat['clean_only'] 
compare_cat['price_other']= compare_cat['other_price']/compare_cat['all_other']

# %%
cols = ['category','price_veganclean','price_vegan','price_clean','price_other']
compare_cat[cols]
# Out:
#                               category  price_veganclean  price_vegan  \
# 0                             cleanser         28.058824    25.555556
# 1  eye-treatment-dark-circle-treatment         58.066667    75.750000
# 2                    facial-treatments         67.534884    55.315361
# 3                       lip-treatments         19.791667    24.000000
# 4        moisturizing-cream-oils-mists         54.950617    60.020658
# 5             sunscreen-sun-protection         37.777778    40.250000
#
#    price_clean  price_other
# 0    37.642857    29.698190
# 1    61.749643    66.067891
# 2    94.408169    72.392887
# 3    17.033333    26.782946
# 4    62.122632    66.839223
# 5    39.857143    49.883621

# %%
import matplotlib.pyplot as plt
import numpy as np


pos = list(range(len(compare_cat['price_vegan'])))
width = 0.175 
    
fig, ax = plt.subplots(figsize=(15,4))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        compare_cat['price_veganclean'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224')

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        compare_cat['price_vegan'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222')

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['post_score'] data,
        compare_cat['price_clean'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E') 

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*3 for p in pos], 
        #using df['post_score'] data,
        compare_cat['price_other'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#8A2BE2')



# Set the y axis label
ax.set_ylabel('$ Dollars')

# Set the chart's title
ax.set_title('Average Price by Product Category')
             
# Set the labels for the x ticks
labels = ['Cleansers', 'Eyes','Treatments','Lips','Moisturizer','Suncare']
ax.set_xticklabels(labels)

# Setting the x-axis and y-axis limits
plt.xlim(0, max(pos)+width*5)
plt.ylim([0, 110] )

# Adding the legend and showing the plot
plt.legend(['Vegan', 'Clean', 'Vegan and Clean', 'All Other'], loc='upper left')
plt.show()

# %%
#NumberLoves vs Rating

# %%
'''skincare_data_1 = skincare_data[skincare_data['vegan_and_clean']==1]
skincare_data_2 =  skincare_data[skincare_data['vegan_only']==1]
skincare_data_3 = skincare_data[skincare_data['clean_only']==1]
skincare_data_4 = skincare_data[skincare_data['all_other']==1]

skincare_data_1['product_type'] = 'Vegan and Clean' 
skincare_data_2['product_type'] = 'Vegan'
skincare_data_3['product_type'] = 'Clean'
skincare_data_4['product_type'] = 'Other''''
# Out:
#   File "<ipython-input-360-bc8bf28b68ed>", line 9
#     skincare_data_4['product_type'] = 'Other''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
test = pd.concat([skincare_data_1, skincare_data_2,skincare_data_3, skincare_data_4], axis=0)

# %%
skincare_data=test

# %%
plt.figure(figsize=(12,12))

'''plt.scatter(skincare_data['rating'], skincare_data['num_loves'],alpha=.75)
plt.title('Number of Loves vs Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Number of Loves')
plt.show()'''


import seaborn as sns
g = sns.scatterplot(x=skincare_data['rating'], y=skincare_data['num_loves'], hue="category", 
              data=skincare_data, s=150, alpha = 0.75,
                    palette=['red','orange','yellow','green','blue','purple'], legend='full')
g.set(yscale="log")
# Out:
# [None]

# %%
plt.figure(figsize=(12,12))

'''plt.scatter(skincare_data['rating'], skincare_data['num_loves'],alpha=.75)
plt.title('Number of Loves vs Average Rating')
plt.xlabel('Average Rating')
plt.ylabel('Number of Loves')
plt.show()'''

import seaborn as sns
g = sns.scatterplot(x=skincare_data['rating'], y=skincare_data['num_loves'], hue="product_type", 
              data=skincare_data, s=100, alpha = 0.75,
                    palette=['#6600cc','#00ff99','#ff6699','#99ccff'], legend='full')
g.set(yscale="log")
# Out:
# [None]

# %%
skincare_datasub = skincare_data[['product_type','rating']]
compare_ratings=skincare_datasub.groupby(['product_type']).mean()

#plt.bar(compare_ratings['product_type'],compare_ratings['rating'],linwidth=2)

# %%
compare_ratings=compare_ratings.reset_index()

# %%
compare_ratings
# Out:
#       product_type    rating
# 0            Clean  4.116194
# 1            Other  4.114509
# 2            Vegan  4.181537
# 3  Vegan and Clean  4.122730

# %%
plt.figure(figsize=(10,4))
plt.xlabel('Average Rating by Product Type', size=15)
plt.bar(compare_ratings['product_type'],compare_ratings['rating'], alpha = 0.25,color='g')
# Out:
# <BarContainer object of 4 artists>

# %%
#INGREDIENT LIST

# %%
# creating ingredient list and counting occurences based on product type

# %%
skincare_data_fil = skincare_data[skincare_data['category']=='moisturizing-cream-oils-mists']
#skincare_data_fil = skincare_data[skincare_data['category']=='facial-treatments']

# %%
veganproducts_base = skincare_data_fil[skincare_data_fil['product_type']=='Vegan']
cleanproducts_base = skincare_data_fil[skincare_data_fil['product_type']=='Clean']
vegan_cleanproducts_base = skincare_data_fil[skincare_data_fil['product_type']=='Vegan and Clean']
otherproducts = skincare_data_fil[skincare_data_fil['product_type']=='Other']

# %%
veganproducts = pd.concat([veganproducts_base,vegan_cleanproducts_base],ignore_index=True)
cleanproducts = pd.concat([cleanproducts_base,vegan_cleanproducts_base],ignore_index=True)
vegan_cleanproducts = pd.concat([veganproducts_base, cleanproducts_base,vegan_cleanproducts_base],ignore_index=True)

# %%
blank_v =[]
for i in veganproducts['ingredients']:
     blank_v.append(i.split(', '))

blank_c =[]
for i in cleanproducts['ingredients']:
     blank_c.append(i.split(', '))

blank_cv =[]
for i in vegan_cleanproducts['ingredients']:
     blank_cv.append(i.split(', '))

blank_o =[]
for i in otherproducts['ingredients']:
     blank_o.append(i.split(', '))

# %%
flat_ingredients_v = [a for sublist in blank_v for a in sublist]
flat_ingredients_c = [a for sublist in blank_c for a in sublist]
flat_ingredients_cv = [a for sublist in blank_cv for a in sublist]
flat_ingredients_o = [a for sublist in blank_o for a in sublist]

# %%
dict_vegan = dict((ingredient, flat_ingredients_v.count(ingredient)) for ingredient in flat_ingredients_v)
dict_clean = dict((ingredient, flat_ingredients_c.count(ingredient)) for ingredient in flat_ingredients_c)
dict_both = dict((ingredient, flat_ingredients_cv.count(ingredient)) for ingredient in flat_ingredients_cv)
dict_other = dict((ingredient, flat_ingredients_o.count(ingredient)) for ingredient in flat_ingredients_o)

# %%
#top20 vegan ingredients - show venn diagram 
top50_vegan = sorted(dict_vegan, key=dict_vegan.get)[-50:] 
top50_clean = sorted(dict_clean, key=dict_clean.get)[-50:] 
top50_both = sorted(dict_both, key=dict_both.get)[-50:] 
top50_other = sorted(dict_clean, key=dict_vegan.get)[-50:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-599-ec9ab1ecf878> in <module>
#       3 top50_clean = sorted(dict_clean, key=dict_clean.get)[-50:]
#       4 top50_both = sorted(dict_both, key=dict_both.get)[-50:]
# ----> 5 top50_other = sorted(dict_clean, key=dict_vegan.get)[-50:]
#
# TypeError: '<' not supported between instances of 'NoneType' and 'int'

# %%
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
plt.figure(figsize=(15,15))
labels = ['Vegan', 'Clean', 'Other']
venn3([set(top50_vegan), set(top50_clean),set(top50_other)],set_labels = labels)
#venn2([set(top50_vegan), set(top50_clean))

# %%
sorted(dict_vegan, key=dict_vegan.get)[-50:] 
#sorted(dict_clean, key=dict_clean.get)[-50:] 
#sorted(dict_both, key=dict_both.get)[-50:] 
#sorted(dict_other, key=dict_other.get)[-50:]
# Out:
# ['styrene)',
#  '1,4 Dioxane in final formulas must comply with the thresholds as follows: (10 or < ppm for products that are meant to be rinsed off',
#  'wiped off or removed',
#  '3ppm or < for products that are meant to remain on the skin).',
#  'Glyceryl Caprylate',
#  'Benzyl Alcohol',
#  'Butyrospermum Parkii (Shea) Butter',
#  'Silica',
#  'Phenoxyethanol.',
#  'Sodium Citrate',
#  'Retinyl Palmitate',
#  'Acrylates/C10-30 Alkyl Acrylate Crosspolymer',
#  'Cetyl Alcohol',
#  'Caffeine',
#  'Rosmarinus Officinalis (Rosemary) Leaf Extract',
#  'Disodium Edta',
#  'Stearic Acid',
#  'Helianthus Annuus (Sunflower) Seed Oil',
#  'Hexylene Glycol',
#  'Maltodextrin',
#  '1,2-Hexanediol',
#  'Polysorbate 20',
#  'Citral',
#  'Lecithin',
#  'Pentylene Glycol',
#  'Citronellol',
#  'Sodium Benzoate',
#  'Geraniol',
#  'Carbomer',
#  'Glyceryl Stearate',
#  'Cetearyl Alcohol',
#  'Sodium Hydroxide',
#  'Tocopheryl Acetate',
#  'Xanthan Gum',
#  'Linalool',
#  'Potassium Sorbate',
#  'Propanediol',
#  'Squalane',
#  'Tocopherol',
#  'Dimethicone',
#  'Caprylic/Capric Triglyceride',
#  'Limonene',
#  'Phenoxyethanol',
#  'Caprylyl Glycol',
#  'Ethylhexylglycerin',
#  'Citric Acid',
#  'Butylene Glycol',
#  'Sodium Hyaluronate',
#  'Water',
#  'Glycerin']

# %%
#looking into which brands carry the most vegan and clean products
test= skincare_data[skincare_data['product_type']=="Vegan and Clean"]

# %%
test['count']=1

# %%
test2 = test[['brand','count']]
test2=test2.groupby('brand').agg(sum)

# %%
test2.sort_values('count',ascending=False)
# Out:
#                      count
# brand
# ORIGINS                 57
# CAUDALIE                25
# COOLA                   20
# PRIMERA                 20
# REN CLEAN SKINCARE      19
# SUPERGOOP!              19
# TATA HARPER             16
# HERBIVORE               14
# BIOSSANCE               13
# DR ROEBUCK'S            13
# FIRST AID BEAUTY        13
# JOSIE MARAN             12
# FARSÁLI                 11
# DRUNK ELEPHANT          11
# KORRES                  10
# KORA ORGANICS           10
# EDIBLE BEAUTY            9
# GLOW RECIPE              8
# TATCHA                   7
# VOLITION BEAUTY          7
# YOUTH TO THE PEOPLE      7
# SKINFIX                  6
# INDIE LEE                5
# FARMACY                  5
# MOON JUICE               4
# ALPYN BEAUTY             4
# LORD JONES               3
# PRIMA                    3
# SUMMER FRIDAYS           2
# MILK MAKEUP              1
# OLEHENRIKSEN             1
# BELIF                    1
# ISLE OF PARADISE         1
# GOOP                     1
# FLORA + BAST             1
# BOSCIA                   1
